# %% [markdown]
# # TEAMNO=8
# SEM=4
# DIV=D
# DEPT=CS

# %% [markdown]
# TITLEID : 4DEDA_CP_04

# %% [markdown]
# # PROJECT TITLE: US ENVIRONMENTAL PROTECTION AGENCY(EPA):AIR

# %% [raw]
# # PROBLEM STATEMENT:This dataset represents daily air quality measurements in UnitedStates
# for 2019 and 2020 in EPA’s Air Quality System. In which both PM2.5 and ozone are  measured
# concurrently.These PM2.5 and ozone concentration data are joined with locational,meteorolog
# -ical,demographic information, and concentrations of other major air quality pollutants when
# available. All of the data were downloaded from AQS with the exception of four demographic
# parameters (people of color, low income, linguistically isolated, and less than high school
# education).These demographic parameters are at the Census "block group" level (area defined
# by the Census Bureau that usually has between 600 and 3,000 people) and listed in fractional
# units for the  block group containing the monitor location.

# %% [raw]
#                 #TEAM DETAILS:

# %% [markdown]
#                 429- 01FE20BCS213-NIKHIL DHUPADAL
#                 421- 01FE20BCS205 -PRASANNA ROOGI
#                 424- 01FE20BCS208 - ASHWINI JANNU
#                 411- 01FE20BCS195 -ACHYUT PADAKI

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Reading the Data

# %%
df=pd.read_excel("C:\\Users\\Nikhil\\Downloads\\epa\\epa\\Datathon_EPA_Air_Quality_Demographics_Meteorology_2019.xlsx")
df
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 129465  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129466  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129467  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129468  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129469  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df.dtypes
# Out:
# AQS_ID                                      object
# LATITUDE                                   float64
# LONGITUDE                                  float64
# COUNTY                                      object
# STATE                                       object
# CBSA                                        object
# PEOPLE_OF_COLOR_FRACTION                   float64
# LOW_INCOME_FRACTION                        float64
# LINGUISTICALLY_ISOLATED_FRACTION           float64
# LESS_THAN_HS_ED_FRACTION                   float64
# DATE                                datetime64[ns]
# TEMPERATURE_CELSIUS                        float64
# RELATIVE_HUMIDITY                          float64
# WIND_SPEED_METERS_PER_SECOND               float64
# WIND_DIRECTION                             float64
# PM25_UG_PER_CUBIC_METER                    float64
# OZONE_PPM                                  float64
# NO2_PPB                                    float64
# ...

# %%
df2=pd.read_excel("C:\\Users\\Nikhil\\Downloads\\epa\\epa\\Datathon_EPA_Air_Quality_Demographics_Meteorology_2020.xlsx")
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %% [markdown]
# #2019 DATA

# %% [markdown]
# # Displaying the first five rows of each attribute

# %%
df.head()
# Out:
#         AQS_ID   LATITUDE  LONGITUDE   COUNTY    STATE  \
# 0  01-003-0010  30.497478 -87.880258  Baldwin  Alabama
# 1  01-003-0010  30.497478 -87.880258  Baldwin  Alabama
# 2  01-003-0010  30.497478 -87.880258  Baldwin  Alabama
# 3  01-003-0010  30.497478 -87.880258  Baldwin  Alabama
# 4  01-003-0010  30.497478 -87.880258  Baldwin  Alabama
#
#                         CBSA  PEOPLE_OF_COLOR_FRACTION  LOW_INCOME_FRACTION  \
# 0  Daphne-Fairhope-Foley, AL                      0.13                 0.26
# 1  Daphne-Fairhope-Foley, AL                      0.13                 0.26
# 2  Daphne-Fairhope-Foley, AL                      0.13                 0.26
# 3  Daphne-Fairhope-Foley, AL                      0.13                 0.26
# 4  Daphne-Fairhope-Foley, AL                      0.13                 0.26
#
#    LINGUISTICALLY_ISOLATED_FRACTION  LESS_THAN_HS_ED_FRACTION  ...  \
# 0                               0.0                      0.03  ...
# ...

# %% [markdown]
# # No Of rows and columns

# %%
df.shape
# Out:
# (129470, 22)

# %%
df2.shape
# Out:
# (133418, 22)

# %% [markdown]
# # description about data

# %%
df.describe().T
# Out:
#                                      count        mean        std         min  \
# LATITUDE                          129470.0   38.533022   4.837426   18.420089
# LONGITUDE                         129470.0  -96.298816  17.693938 -158.088613
# PEOPLE_OF_COLOR_FRACTION          129393.0    0.383927   0.303357    0.000000
# LOW_INCOME_FRACTION               129393.0    0.375089   0.215389    0.000000
# LINGUISTICALLY_ISOLATED_FRACTION  129393.0    0.049076   0.091215    0.000000
# LESS_THAN_HS_ED_FRACTION          129393.0    0.147154   0.129474    0.000000
# TEMPERATURE_CELSIUS                72703.0   13.576014  10.547154  -34.814816
# RELATIVE_HUMIDITY                  50670.0   63.095606  18.520436    1.083333
# WIND_SPEED_METERS_PER_SECOND       58576.0    2.250522   5.239192    0.000000
# WIND_DIRECTION                     59484.0  189.811975  62.589750    6.375000
# PM25_UG_PER_CUBIC_METER           129470.0    6.962038   4.498417   -4.300000
# ...

# %%
df2.describe().T
# Out:
#                                      count        mean        std         min  \
# LATITUDE                          133418.0   38.396963   4.753737   18.420089
# LONGITUDE                         133418.0  -96.290902  17.555206 -158.088613
# PEOPLE_OF_COLOR_FRACTION          133404.0    0.387406   0.304613    0.000000
# LOW_INCOME_FRACTION               133404.0    0.376489   0.214970    0.000000
# LINGUISTICALLY_ISOLATED_FRACTION  133404.0    0.050916   0.094638    0.000000
# LESS_THAN_HS_ED_FRACTION          133404.0    0.146932   0.130830    0.000000
# TEMPERATURE_CELSIUS                71845.0   14.628471   9.979496  -36.018517
# RELATIVE_HUMIDITY                  49413.0   60.331166  19.754614    3.541667
# WIND_SPEED_METERS_PER_SECOND       59659.0    2.151579   1.410811    0.019292
# WIND_DIRECTION                     60329.0  191.810643  62.588574    2.416667
# PM25_UG_PER_CUBIC_METER           133418.0    7.918043   8.657031   -4.900000
# ...

# %% [markdown]
# # DATA DEMOGRAPHICS

# %% [markdown]
# # NULL VALUES IN EACH ATTRIBUTE

# %%
df.isnull().sum()
# Out:
# null     0
# count    0
# dtype: int64

# %%
df2.isnull().sum()

# %%
df = pd.DataFrame(df.isna().sum().sort_values(ascending=False))
df['null']=df.index
df['count']=df.iloc[:,:-1]
df.reset_index(drop=True, inplace=True)
df = df.drop(df.columns[[0]],axis = 1)
plt.title('Null Distribution Column-Wise')
ax = sns.barplot(y='null',x='count',data=df.head(14))
for i in ax.containers:
    ax.bar_label(i)

# %%
df2 = pd.DataFrame(df2.isna().sum().sort_values(ascending=False))
df2['null']=df2.index
df2['count']=df2.iloc[:,:-1]
df2.reset_index(drop=True, inplace=True)
df2 = df2.drop(df2.columns[[0]],axis = 1)
plt.title('Null Distribution Column-Wise')
ax = sns.barplot(y='null',x='count',data=df2.head(14))
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# # Out of 129470 rows 128811 values in column LEAD_UG_PER_CUBIC_METER & 126163 values in column BENZENE_PPBC are missing
#
# It is better to drop these columns as they contain mostly null values

# %%
df.drop('BENZENE_PPBC',axis=1,inplace=True)

# %%
df2.drop('BENZENE_PPBC',axis=1,inplace=True)

# %%
df.drop('LEAD_UG_PER_CUBIC_METER',axis=1,inplace=True)

# %%
df2.drop('LEAD_UG_PER_CUBIC_METER',axis=1,inplace=True)

# %%
df
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 129465  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129466  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129467  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129468  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129469  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %% [markdown]
# df2

# %%
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %% [markdown]
# # Filling the missing values

# %%
df.skew(axis = 0, skipna = True)
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_10012/2838370498.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew(axis = 0, skipna = True)
# LATITUDE                             -0.128118
# LONGITUDE                            -0.384259
# PEOPLE_OF_COLOR_FRACTION              0.524450
# LOW_INCOME_FRACTION                   0.395201
# LINGUISTICALLY_ISOLATED_FRACTION      3.181499
# LESS_THAN_HS_ED_FRACTION              1.519445
# TEMPERATURE_CELSIUS                  -0.610941
# RELATIVE_HUMIDITY                    -0.528938
# WIND_SPEED_METERS_PER_SECOND        116.816549
# WIND_DIRECTION                       -0.087643
# PM25_UG_PER_CUBIC_METER               2.207218
# OZONE_PPM                             0.141793
# NO2_PPB                               1.646966
# ...

# %%
df2.skew(axis = 0, skipna = True)
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_10012/2329835753.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.skew(axis = 0, skipna = True)
# LATITUDE                            -0.238675
# LONGITUDE                           -0.368437
# PEOPLE_OF_COLOR_FRACTION             0.503311
# LOW_INCOME_FRACTION                  0.389912
# LINGUISTICALLY_ISOLATED_FRACTION     3.126420
# LESS_THAN_HS_ED_FRACTION             1.523369
# TEMPERATURE_CELSIUS                 -0.406749
# RELATIVE_HUMIDITY                   -0.418839
# WIND_SPEED_METERS_PER_SECOND         1.853720
# WIND_DIRECTION                      -0.212295
# PM25_UG_PER_CUBIC_METER             10.356391
# OZONE_PPM                            0.428942
# NO2_PPB                              1.741153
# CO_PPM                               1.924388
# ...

# %% [markdown]
# #SKEWNESS EXITS FOR EACH ATTRIBUTE SO FILL THE MISSING VALUES WITH MEDIAN

# %%
df = df.fillna(df.median())
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_9708/3493596106.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df = df.fillna(df.median())
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_9708/3493596106.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df = df.fillna(df.median())

# %%
df
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 129465  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129466  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129467  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129468  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129469  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2 = df2.fillna(df2.median())
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_9708/529729174.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df2 = df2.fillna(df2.median())
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_9708/529729174.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2 = df2.fillna(df2.median())

# %%
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %% [markdown]
# df2

# %%
df['AQI _PM2.5']=(150-101)/(55-35)*(df['PM25_UG_PER_CUBIC_METER']-35)+101
df
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 129465  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129466  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129467  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129468  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129469  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2['AQI _PM2.5']=(150-101)/(55-35)*(df2['PM25_UG_PER_CUBIC_METER']-35)+101
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df['AQI _Ozone']=(121-101)/(0.085-0.071)*(df['OZONE_PPM']-0.071)+101
df
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 129465  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129466  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129467  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129468  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129469  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2['AQI _Ozone']=(121-101)/(0.085-0.071)*(df2['OZONE_PPM']-0.071)+101
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df['AQI _NO2']=(150-101)/(200-100)*(df['NO2_PPB']-100)+101
df
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 129465  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129466  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129467  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129468  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 129469  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2['AQI _NO2']=(150-101)/(200-100)*(df2['NO2_PPB']-100)+101
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df.corr()
# Out:
#                                   LATITUDE  LONGITUDE  \
# LATITUDE                          1.000000   0.189144
# LONGITUDE                         0.189144   1.000000
# PEOPLE_OF_COLOR_FRACTION         -0.459217  -0.226355
# LOW_INCOME_FRACTION              -0.214326  -0.106536
# LINGUISTICALLY_ISOLATED_FRACTION -0.218141  -0.230683
# LESS_THAN_HS_ED_FRACTION         -0.265301  -0.152433
# TEMPERATURE_CELSIUS              -0.325016  -0.036953
# RELATIVE_HUMIDITY                 0.081870   0.176468
# WIND_SPEED_METERS_PER_SECOND      0.035420   0.000623
# WIND_DIRECTION                    0.080472  -0.023527
# PM25_UG_PER_CUBIC_METER          -0.146103   0.082632
# OZONE_PPM                        -0.094163  -0.073068
# NO2_PPB                          -0.090964  -0.079982
# CO_PPM                           -0.049915  -0.139821
# SO2_PPB                           0.151607  -0.073770
# AQI _PM2.5                       -0.146103   0.082632
# ...

# %%
data=sns.heatmap(df.corr(),annot=True)
sns.set(rc = {'figure.figsize':(15,8)})
plt.show()

# %%
df2.corr()
# Out:
#                                   LATITUDE  LONGITUDE  \
# LATITUDE                          1.000000   0.205458
# LONGITUDE                         0.205458   1.000000
# PEOPLE_OF_COLOR_FRACTION         -0.469527  -0.228836
# LOW_INCOME_FRACTION              -0.200720  -0.102953
# LINGUISTICALLY_ISOLATED_FRACTION -0.221333  -0.233782
# LESS_THAN_HS_ED_FRACTION         -0.271439  -0.144884
# TEMPERATURE_CELSIUS              -0.323958  -0.061649
# RELATIVE_HUMIDITY                 0.046220   0.222728
# WIND_SPEED_METERS_PER_SECOND      0.139280  -0.015631
# WIND_DIRECTION                    0.117044  -0.033013
# PM25_UG_PER_CUBIC_METER          -0.103192  -0.129887
# OZONE_PPM                        -0.062433  -0.140705
# NO2_PPB                          -0.091572  -0.107578
# CO_PPM                           -0.077647  -0.170699
# SO2_PPB                           0.114961  -0.039318
# AQI _PM2.5                       -0.103192  -0.129887
# ...

# %%
data=sns.heatmap(df2.corr(),annot=True)
sns.set(rc = {'figure.figsize':(15,8)})
plt.show()

# %%
# Co-Relation=1 indicates it is perfectly co-related
#Co-Relation=-1 indicates it is negatively co-related
#Co-Relation is negative means it is negatively co-related
#Co-Relation is positive means it is postively co-related

# %% [markdown]
# # AQI(PM 2.5) ACROSS EACH CBSA(CORE BASED STATISTICAL AREAS)

# %%
results21=df2.groupby('COUNTY').mean()
condes21=results21.head(10)
condes21
# Out:
#             LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# COUNTY
# Ada        43.600699 -116.347853                  0.240000
# Adams      39.920020  -77.309680                  0.040000
# Alachua    29.566112  -82.266080                  0.260000
# Alameda    37.777059 -122.133913                  0.603943
# Albany     42.680750  -73.757330                  0.260000
# Albemarle  38.076570  -78.503970                  0.140000
# Allegan    42.767786  -86.148577                  0.160000
# Allegheny  40.479260  -79.953084                  0.147432
# Allen      40.965692  -84.683736                  0.294456
# Anoka      45.137680  -93.207615                  0.260000
#
#            LOW_INCOME_FRACTION  LINGUISTICALLY_ISOLATED_FRACTION  \
# COUNTY
# Ada                   0.380000                          0.010000
# Adams                 0.240000                          0.000000
# Alachua               0.340000                          0.000000
# ...

# %%
results2=df2.groupby('STATE').mean()
results2
# Out:
#                        LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# STATE
# Alabama               33.065555  -86.560100                  0.660269
# Alaska                64.845690 -147.727413                  0.410000
# Arizona               33.357849 -112.341059                  0.632436
# Arkansas              35.129339  -92.223945                  0.707303
# California            36.276035 -120.020222                  0.563170
# Colorado              39.570741 -106.572988                  0.272141
# Connecticut           41.559874  -72.890454                  0.562568
# Delaware              39.230473  -75.612726                  0.427574
# District Of Columbia  38.908747  -76.985703                  0.834592
# Florida               28.178826  -81.925906                  0.453114
# Georgia               33.436854  -83.599729                  0.693340
# Hawaii                21.313563 -157.979892                  0.860000
# ...

# %%
results7=df.groupby('STATE').mean()
results7
# Out:
#                        LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# STATE
# Alabama               33.041534  -86.593824                  0.655300
# Alaska                64.845690 -147.727413                  0.410000
# Arizona               33.355098 -112.344341                  0.632224
# Arkansas              35.129111  -92.230771                  0.708000
# California            36.292674 -120.048210                  0.559348
# Colorado              39.435073 -106.660841                  0.271490
# Connecticut           41.559692  -72.882418                  0.566519
# Delaware              39.219998  -75.615126                  0.397265
# District Of Columbia  38.908766  -76.985743                  0.834378
# Florida               28.215619  -81.915473                  0.460003
# Georgia               33.431368  -83.577018                  0.695773
# Hawaii                21.313156 -157.975543                  0.860800
# ...

# %%
results8=df2.groupby('STATE').mean()
results8
# Out:
#                        LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# STATE
# Alabama               33.065555  -86.560100                  0.660269
# Alaska                64.845690 -147.727413                  0.410000
# Arizona               33.357849 -112.341059                  0.632436
# Arkansas              35.129339  -92.223945                  0.707303
# California            36.276035 -120.020222                  0.563170
# Colorado              39.570741 -106.572988                  0.272141
# Connecticut           41.559874  -72.890454                  0.562568
# Delaware              39.230473  -75.612726                  0.427574
# District Of Columbia  38.908747  -76.985703                  0.834592
# Florida               28.178826  -81.925906                  0.453114
# Georgia               33.436854  -83.599729                  0.693340
# Hawaii                21.313563 -157.979892                  0.860000
# ...

# %%
results=df.groupby('COUNTY').mean()
results
# Out:
#             LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# COUNTY
# Ada        43.600699 -116.347853                  0.240000
# Adams      39.920020  -77.309680                  0.040000
# Alachua    29.566112  -82.266080                  0.260000
# Alameda    37.776646 -122.133064                  0.605317
# Albany     42.680750  -73.757330                  0.260000
# ...              ...         ...                       ...
# Wright     45.209160  -93.669210                  0.130000
# Wyandotte  39.117219  -94.635605                  0.960000
# Yolo       38.661210 -121.732690                  0.560000
# York       37.835363  -78.459439                  0.317448
# Yuma       32.690278 -114.614440                  0.860000
#
#            LOW_INCOME_FRACTION  LINGUISTICALLY_ISOLATED_FRACTION  \
# COUNTY
# Ada                   0.380000                          0.010000
# Adams                 0.240000                          0.000000
# ...

# %%
cbsa1 = df.groupby('CBSA').mean().sort_values(['AQI _PM2.5'], axis=0, ascending=True)
condes = cbsa1.head(10)
condes
# Out:
#                         LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# CBSA
# Helena, MT             46.850500 -111.987164                  0.030000
# Casper, WY             42.822310 -106.365010                  0.160000
# Riverton, WY           42.791445 -108.165252                  0.085261
# Rapid City, SD         43.557640 -103.483860                  0.070000
# Jackson, WY-ID         43.482560 -110.745260                  0.150000
# Santa Fe, NM           35.619750 -106.079680                  0.830000
# Urban Honolulu, HI     21.313156 -157.975543                  0.860800
# Tucson, AZ             32.295150 -110.982300                  0.280000
# Manchester-Nashua, NH  42.861830  -71.878626                  0.070000
# Clearlake, CA          39.018930 -122.913330                  0.510000
#
#                        LOW_INCOME_FRACTION  LINGUISTICALLY_ISOLATED_FRACTION  \
# CBSA
# Helena, MT                        0.290000                            0.0000
# ...

# %%
cbsa2 = df2.groupby('CBSA').mean().sort_values(['AQI _PM2.5'], axis=0, ascending=True)
condes2 = cbsa2.head(10)
condes2
# Out:
#                         LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# CBSA
# Helena, MT             46.850500 -111.987164                  0.030000
# Manchester-Nashua, NH  42.861830  -71.878626                  0.070000
# Rapid City, SD         43.557640 -103.483860                  0.070000
# Wilmington, NC         34.364167  -77.838611                  0.000000
# Cheyenne, WY           41.147894 -104.687754                  0.036456
# Casper, WY             42.822310 -106.365010                  0.160000
# Rock Springs, WY       41.556430 -109.530440                  0.390000
# Riverton, WY           42.814428 -108.228066                  0.123355
# Dickinson, ND          46.894300 -103.378530                  0.080000
# Urban Honolulu, HI     21.313563 -157.979892                  0.860000
#
#                        LOW_INCOME_FRACTION  LINGUISTICALLY_ISOLATED_FRACTION  \
# CBSA
# Helena, MT                        0.290000                             0.000
# ...

# %% [markdown]
# # AQI_PM2.5 IN EACH CBSA TOP 10 ASCENDING ORDER

# %%
# plt.figure(figsize=(16,8).dpi=150)
# condes['AQI_PM2.5'].plot(label='AQI_PM2.5',color='orange')
# condes2['AQI_PM2.5'].plot(label='AQ_PM2.5')
# plt.title('AQI_PM2.5')
# plt.xticks(CBSA)
# plt.xlabel('CBSA')
# plt.legend
cbsa=condes.index
plt.figure(figsize=(18,8))
plt.plot(cbsa,condes['AQI _PM2.5'],label='2019')
plt.plot(cbsa,condes2['AQI _PM2.5'],label='2020')
plt.xticks(cbsa,rotation='vertical')
plt.legend()
plt.ylabel('AQI_PM2.5')
plt.xlabel('CBSA')
plt.grid(axis='y')
plt.show()

# %%
cbsa18 = df.groupby('CBSA').mean().sort_values(['AQI _PM2.5'], axis=0, ascending=False)
condes7 = cbsa18.head(10)
condes7
# Out:
#                                    LATITUDE   LONGITUDE  \
# CBSA
# Visalia-Porterville, CA           36.332179 -119.291228
# Hanford-Corcoran, CA              36.315670 -119.643447
# Indianapolis-Carmel-Anderson, IN  39.799624  -86.122489
# McAllen-Edinburg-Mission, TX      26.226210  -98.291069
# San Diego-Carlsbad, CA            33.005840 -117.040426
# Athens-Clarke County, GA          33.918137  -83.344385
# El Centro, CA                     32.704450 -115.502557
# Birmingham-Hoover, AL             33.512476  -86.823447
# Oklahoma City, OK                 35.468415  -97.479551
# State College, PA                 40.811389  -77.877028
#
#                                   PEOPLE_OF_COLOR_FRACTION  \
# CBSA
# Visalia-Porterville, CA                           0.480000
# Hanford-Corcoran, CA                              0.900000
# Indianapolis-Carmel-Anderson, IN                  0.686325
# McAllen-Edinburg-Mission, TX                      0.880000
# ...

# %%
cbsa181 = df2.groupby('CBSA').mean().sort_values(['AQI _PM2.5'], axis=0, ascending=False)
condes71 = cbsa181.head(10)
condes71
# Out:
#                           LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# CBSA
# Visalia-Porterville, CA  36.332179 -119.291228                  0.480000
# Bishop, CA               37.361048 -118.352505                  0.532752
# Hanford-Corcoran, CA     36.315670 -119.643447                  0.900000
# Madera, CA               36.953256 -120.034203                  0.680000
# Fresno, CA               36.806697 -119.880678                  0.521347
# Yuba City, CA            39.138773 -121.618549                  0.220000
# Chico, CA                39.761680 -121.840470                  0.180000
# Modesto, CA              37.566343 -120.916243                  0.390143
# Bakersfield, CA          35.216644 -118.647991                  0.644652
# Merced, CA               37.281853 -120.433671                  0.840000
#
#                          LOW_INCOME_FRACTION  \
# CBSA
# Visalia-Porterville, CA             0.660000
# Bishop, CA                          0.400000
# ...

# %% [markdown]
# # TOP 10 AQI_PM2.5 IN DECREASING ORDER

# %%
cbsa=condes7.index
plt.figure(figsize=(18,8))
plt.plot(cbsa,condes7['AQI _PM2.5'],label='2019')
plt.plot(cbsa,condes71['AQI _PM2.5'],label='2020')
plt.xticks(cbsa,rotation='vertical')
plt.legend(loc='upper left')
plt.ylabel('AQI_PM2.5')
plt.xlabel('CBSA')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# # AQI_OZONE IN EACH CBSA(TOP 10)

# %%
cbsa=condes7.index
plt.figure(figsize=(18,8))
plt.bar(cbsa,condes7['AQI _Ozone'],width=-0.2,label='2019',align='edge')
plt.bar(cbsa,condes71['AQI _Ozone'],width=+0.2,label='2020',align='edge')
plt.xticks(cbsa,rotation='vertical')
plt.legend(loc='upper left')
plt.ylabel('AQI_PM2.5')
plt.xlabel('CBSA')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# # AQI_No2 In Each Cbsa

# %%
cbsa=condes7.index
plt.figure(figsize=(18,8))
plt.bar(cbsa,condes7['AQI _NO2'],width=-0.2,label='2019',align='edge')
plt.bar(cbsa,condes71['AQI _NO2'],width=+0.2,label='2020',align='edge')
plt.xticks(cbsa,rotation='vertical')
plt.legend(loc='upper left')
plt.ylabel('AQI_No2')
plt.xlabel('CBSA')
plt.grid(axis='y')

plt.show()

# %% [markdown]
# # AQI_PM2.5 ACROSS EACH STATE

# %%
states=results7.index
plt.figure(figsize=(18,8))
plt.bar(states,results7['AQI _PM2.5'],width=-0.4,label='2019',align='edge')
plt.bar(states,results2['AQI _PM2.5'],width=+0.4,label='2020',align='edge')
plt.xticks(states,rotation='vertical')
plt.legend()
plt.ylabel('AQI_Pm2.5')
plt.xlabel('states')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #AQI_NO2 across each state

# %%
state44 = df.groupby('STATE').mean().sort_values(['AQI _NO2'], axis=0, ascending=False)
states55 = state44.head(10)
states55
# Out:
#                        LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# STATE
# District Of Columbia  38.908766  -76.985743                  0.834378
# Washington            47.825095 -122.391065                  0.391328
# Utah                  40.330849 -111.780619                  0.229092
# New Jersey            40.234176  -74.738672                  0.413062
# New York              42.008196  -75.709411                  0.426274
# Oregon                45.187205 -122.751036                  0.252553
# Idaho                 43.600699 -116.347853                  0.240000
# Colorado              39.435073 -106.660841                  0.271490
# Louisiana             30.626794  -91.575329                  0.541674
# Arkansas              35.129111  -92.230771                  0.708000
#
#                       LOW_INCOME_FRACTION  LINGUISTICALLY_ISOLATED_FRACTION  \
# STATE
# District Of Columbia             0.210000                          0.050043
# ...

# %%
state444 = df2.groupby('STATE').mean().sort_values(['AQI _NO2'], axis=0, ascending=False)
states555 = state44.head(10)
states555
# Out:
#                        LATITUDE   LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# STATE
# District Of Columbia  38.908766  -76.985743                  0.834378
# Washington            47.825095 -122.391065                  0.391328
# Utah                  40.330849 -111.780619                  0.229092
# New Jersey            40.234176  -74.738672                  0.413062
# New York              42.008196  -75.709411                  0.426274
# Oregon                45.187205 -122.751036                  0.252553
# Idaho                 43.600699 -116.347853                  0.240000
# Colorado              39.435073 -106.660841                  0.271490
# Louisiana             30.626794  -91.575329                  0.541674
# Arkansas              35.129111  -92.230771                  0.708000
#
#                       LOW_INCOME_FRACTION  LINGUISTICALLY_ISOLATED_FRACTION  \
# STATE
# District Of Columbia             0.210000                          0.050043
# ...

# %%
states=states55.index
plt.figure(figsize=(18,8))
plt.bar(states,states55['AQI _NO2'],width=-0.2,label='2019',align='edge')
plt.bar(states,states555['AQI _NO2'],width=+0.2,label='2020',align='edge')
plt.xticks(states,rotation='vertical')
plt.legend()
plt.ylabel('No2_PPB')
plt.xlabel('states')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # AQI_Ozone Across Each State

# %%
states=states55.index
plt.figure(figsize=(18,8))
plt.bar(states,states55['AQI _Ozone'],width=-0.2,label='2019',align='edge')
plt.bar(states,states555['AQI _Ozone'],width=+0.2,label='2020',align='edge')
plt.xticks(states,rotation='vertical')
plt.legend()
plt.ylabel('OZONE')
plt.xlabel('states')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # So2 Concentration Across States

# %%
states=results8.index
plt.figure(figsize=(18,8))
plt.bar(states,results7['SO2_PPB'],width=-0.4,label='2019',align='edge')
plt.bar(states,results8['SO2_PPB'],width=+0.4,label='2020',align='edge')
plt.xticks(states,rotation='vertical')
plt.legend()
plt.ylabel('SO2_PPB')
plt.xlabel('states')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Co concentration Across Each State

# %%
states=results8.index
plt.figure(figsize=(18,8))
plt.bar(states,results7['CO_PPM'],width=-0.4,label='2019',align='edge')
plt.bar(states,results8['CO_PPM'],width=+0.4,label='2020',align='edge')
plt.xticks(states,rotation='vertical')
plt.legend()
plt.ylabel('CO_PPM')
plt.xlabel('states')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # STATES HAVING HIGHEST LOWINCOME FRACTION

# %%
states=results8.index
plt.figure(figsize=(18,8))
plt.bar(states,results7['LOW_INCOME_FRACTION'],width=-0.4,label='2019',align='edge')
plt.bar(states,results8['LOW_INCOME_FRACTION'],width=+0.4,label='2020',align='edge')
plt.xticks(states,rotation='vertical')
plt.legend()
plt.ylabel('Low income Fraction')
plt.xlabel('states')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # AIR QUALITY OF YEAR 2020

# %%
df2.shape
# Out:
# (133418, 22)

# %%
df2.describe().T
# Out:
#                                      count        mean        std         min  \
# LATITUDE                          133418.0   38.396963   4.753737   18.420089
# LONGITUDE                         133418.0  -96.290902  17.555206 -158.088613
# PEOPLE_OF_COLOR_FRACTION          133404.0    0.387406   0.304613    0.000000
# LOW_INCOME_FRACTION               133404.0    0.376489   0.214970    0.000000
# LINGUISTICALLY_ISOLATED_FRACTION  133404.0    0.050916   0.094638    0.000000
# LESS_THAN_HS_ED_FRACTION          133404.0    0.146932   0.130830    0.000000
# TEMPERATURE_CELSIUS                71845.0   14.628471   9.979496  -36.018517
# RELATIVE_HUMIDITY                  49413.0   60.331166  19.754614    3.541667
# WIND_SPEED_METERS_PER_SECOND       59659.0    2.151579   1.410811    0.019292
# WIND_DIRECTION                     60329.0  191.810643  62.588574    2.416667
# PM25_UG_PER_CUBIC_METER           133418.0    7.918043   8.657031   -4.900000
# ...

# %% [markdown]
# #DATA DEMOGRAPHICS

# %%
df2.isnull().sum()
# Out:
# null     0
# count    0
# dtype: int64

# %%
df2.drop('BENZENE_PPBC',axis=1,inplace=True)

# %%
df2.drop('LEAD_UG_PER_CUBIC_METER',axis=1,inplace=True)

# %%
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %% [markdown]
# # ITS BETTER TO DROP COLUMNS BENZENE_PPBC AND LEAD_UG_CUBIC_METER

# %%
df2 = pd.DataFrame(df2.isna().sum().sort_values(ascending=False))
df2['null']=df2.index
df2['count']=df2.iloc[:,:-1]
df2.reset_index(drop=True, inplace=True)
df2 = df2.drop(df2.columns[[0]],axis = 1)
plt.title('Null Distribution Column-Wise')
ax = sns.barplot(y='null',x='count',data=df2.head(14))
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# #Filling the Missing Value

# %%
df2.skew(axis = 0, skipna = True)
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_22692/2329835753.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.skew(axis = 0, skipna = True)
# LATITUDE                            -0.238675
# LONGITUDE                           -0.368437
# PEOPLE_OF_COLOR_FRACTION             0.503311
# LOW_INCOME_FRACTION                  0.389912
# LINGUISTICALLY_ISOLATED_FRACTION     3.126420
# LESS_THAN_HS_ED_FRACTION             1.523369
# TEMPERATURE_CELSIUS                 -0.406749
# RELATIVE_HUMIDITY                   -0.418839
# WIND_SPEED_METERS_PER_SECOND         1.853720
# WIND_DIRECTION                      -0.212295
# PM25_UG_PER_CUBIC_METER             10.356391
# OZONE_PPM                            0.428942
# NO2_PPB                              1.741153
# CO_PPM                               1.924388
# ...

# %% [markdown]
# #Skewness exits for each attribute hence we can fill the values with median

# %%
df2 = df2.fillna(df2.median())
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_22692/529729174.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df2 = df2.fillna(df2.median())
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_22692/529729174.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2 = df2.fillna(df2.median())

# %%
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2.corr()
# Out:
#                                   LATITUDE  LONGITUDE  \
# LATITUDE                          1.000000   0.205458
# LONGITUDE                         0.205458   1.000000
# PEOPLE_OF_COLOR_FRACTION         -0.469527  -0.228836
# LOW_INCOME_FRACTION              -0.200720  -0.102953
# LINGUISTICALLY_ISOLATED_FRACTION -0.221333  -0.233782
# LESS_THAN_HS_ED_FRACTION         -0.271439  -0.144884
# TEMPERATURE_CELSIUS              -0.323958  -0.061649
# RELATIVE_HUMIDITY                 0.046220   0.222728
# WIND_SPEED_METERS_PER_SECOND      0.139280  -0.015631
# WIND_DIRECTION                    0.117044  -0.033013
# PM25_UG_PER_CUBIC_METER          -0.103192  -0.129887
# OZONE_PPM                        -0.062433  -0.140705
# NO2_PPB                          -0.091572  -0.107578
# CO_PPM                           -0.077647  -0.170699
# SO2_PPB                           0.114961  -0.039318
#
#                                   PEOPLE_OF_COLOR_FRACTION  \
# ...

# %%
data=sns.heatmap(df2.corr(),annot=True)
sns.set(rc = {'figure.figsize':(15,8)})
plt.show()

# %%
df2['AQI _PM2.5']=(150-101)/(55-35)*(df2['PM25_UG_PER_CUBIC_METER']-35)+101
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2['AQI _Ozone']=(121-101)/(0.085-0.071)*(df2['OZONE_PPM']-0.071)+101
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %%
df2['AQI _NO2']=(150-101)/(200-100)*(df2['NO2_PPB']-100)+101
df2
# Out:
#              AQS_ID   LATITUDE  LONGITUDE   COUNTY        STATE  \
# 0       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 1       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 2       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 3       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# 4       01-003-0010  30.497478 -87.880258  Baldwin      Alabama
# ...             ...        ...        ...      ...          ...
# 133413  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133414  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133415  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133416  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
# 133417  72-021-0010  18.420089 -66.150615  Bayamon  Puerto Rico
#
#                                 CBSA  PEOPLE_OF_COLOR_FRACTION  \
# 0          Daphne-Fairhope-Foley, AL                      0.13
# 1          Daphne-Fairhope-Foley, AL                      0.13
# ...

# %% [markdown]
# # concentartion of ozone_ppm across each state

# %%
res=df2.groupby('STATE').sum()
res
# Out:
#                            LATITUDE     LONGITUDE  PEOPLE_OF_COLOR_FRACTION  \
# STATE
# Alabama                35644.668259 -9.331179e+04                    711.77
# Alaska                 10180.773330 -2.319320e+04                     64.37
# Arizona               119287.668974 -4.017316e+05                   2261.59
# Arkansas               20972.215621 -5.505770e+04                    422.26
# California            907227.348017 -3.001586e+06                  14084.32
# Colorado               79299.765880 -2.135723e+05                    545.37
# Connecticut            60677.416430 -1.064201e+05                    821.35
# Delaware               49312.704048 -9.504520e+04                    537.46
# District Of Columbia   27625.210020 -5.465985e+04                    592.56
# Florida               129059.022668 -3.752206e+05                   2075.26
# Georgia                51058.076078 -1.276568e+05                   1058.73
# ...

# %% [markdown]
# calfornia have max conc of ozone

# %% [markdown]
# # Concentration of S02 and no2 across each state

# %%
states=res.index
plt.figure(figsize=(18,8))
SO2_PPB=res['SO2_PPB']
NO2_PPB=res['NO2_PPB']
plt.bar(states,SO2_PPB,width=-0.2,label='SO2 concentration',align='edge')
plt.bar(states ,NO2_PPB,width=0.2,label='NO2 concentartion',align='edge')
plt.xlabel('states')
plt.ylabel('conc of pollutants')
plt.legend(loc='upper left')
plt.title(' conc of pollutants')
plt.xticks(states,rotation='vertical')
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('So2 and no2 concentration')
plt.show()

# %%
no_19 = df["NO2_PPB"].mean()
no_20 = df2["NO2_PPB"].mean()


co_19 = df["CO_PPM"].mean()
co_20 = df2["CO_PPM"].mean()
so_19 = df["SO2_PPB"].mean()
so_20 = df2["SO2_PPB"].mean()


ozone_19 = df["OZONE_PPM"].mean()
ozone_20 = df2["OZONE_PPM"].mean()
pm_19 = df["PM25_UG_PER_CUBIC_METER"].mean()
pm_20 = df2["PM25_UG_PER_CUBIC_METER"].mean()

# %%
x = [co_19, pm_19,ozone_19,so_19,no_19]
labels = ['CO',"PM 2.5"," Ozone",'SO2','NO2']
plt.subplot(1,2,1)
plt.pie(x,labels = labels,autopct='%.0f%%',radius=1)
plt.title("Concentration of polluatants in 2019",pad=70)
plt.show()

# 2020 Plot
x = [co_20, pm_20,ozone_20,so_20,no_20]
labels = ['CO',"PM 2.5"," Ozone",'SO2','NO2']
plt.subplot(1,2,2)
plt.pie(x,labels = labels,autopct='%.0f%%',radius=1)
plt.title("Concentration of  polluatnts in 2020",pad=70)
plt.show()
